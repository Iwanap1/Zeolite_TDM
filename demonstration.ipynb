# %%
import os
from dotenv import load_dotenv
from pathlib import Path
from corpus_acquisition import collect_elsevier_papers, ElsevierParser
from paragraph_classification import *

# %%
### Download Papers
API_KEY = os.getenv("ELSEVIER") # replace with your own API key
collect_elsevier_papers(
    query="KEY(hierarchical zeolite)",
    paper_count=15,
    api_key=API_KEY
)
# Out:
# ...
# Successfully collected 15 papers.
# Failed to collect 0 papers.

# %%
parser = ElsevierParser()
parser.parse_directory('data/xml')
parser.save_to_json('data/parsed.json')
# Out:
# Label not found in table in data/xml/S2949839225000446.xml
# ✅ Saved 15 documents to data/parsed.json

# %%
# choose BERT model (from hf transformers) and decide wether to use CLS token (use_cls=True) or mean pooling (use_cls=False), ensure head matches these choices else classification will be poor
paragraph_classification_from_json(
    bert_model='/Users/iwanpavord/desktop/project/tdm_catalysis/models/matbert/matbert-base-uncased', 
    head='models/matbert_bsc_cls.pth',
    batch_size=16,
    input_path='data/parsed.json',
    output_path='data/synthesis_paragraphs.json',
    use_cls=True
    )
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at /Users/iwanpavord/desktop/project/tdm_catalysis/models/matbert/matbert-base-uncased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
